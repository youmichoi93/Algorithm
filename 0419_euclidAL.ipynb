# %%
def euclid(x,y):
  t = x % y       # x와 y 두수의 나머지 t 구한다.


  while (t !=0):  #반복문 (조건 t !=0)
    x,y = y,t     #y를 x에 t를 y에
    t = x % y     #x와 y의 나머지 t를 구한다.
  return y        #return y값을 반환


euclid(221,143)
# Out:
# 13
